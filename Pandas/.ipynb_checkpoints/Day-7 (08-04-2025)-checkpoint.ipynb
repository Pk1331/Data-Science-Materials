# %%
import pandas as pd

# %% [markdown]
# ---
# ## **11. Merging Functions**

# %% [markdown]
# #### **Merging** is like SQL joins – you combine rows from two dataframes based on a common column.
# ```python
# pd.merge(
#     left,                      # Left DataFrame
#     right,                     # Right DataFrame
#     how="inner",               # Type of join: 'left', 'right', 'outer', 'inner'
#     on=None,                   # Column(s) to join on (must be common in both)
#     left_on=None,              # Column(s) from left DataFrame to join on
#     right_on=None,             # Column(s) from right DataFrame to join on
#     left_index=False,          # Use index from left DataFrame
#     right_index=False,         # Use index from right DataFrame
#     sort=False,                # Sort the result by join keys
#     suffixes=("_x", "_y"),     # Suffix to apply to overlapping column names
#     copy=True,                 # Always copy data (default True)
#     indicator=False,           # Add column to indicate source of row (True / str)
#     validate=None              # Check if merge is one-to-one, one-to-many etc.
# )
#
# ```

# %%
df1 = pd.read_csv("datasets/employee.csv")
df1
# Out:
#     EmployeeID          Name  Age  DepartmentID  Salary
# 0         1001    Employee_1   50           201   71576
# 1         1002    Employee_2   36           203   64353
# 2         1003    Employee_3   29           201   42675
# 3         1004    Employee_4   42           203   77733
# 4         1005    Employee_5   40           202   69417
# ..         ...           ...  ...           ...     ...
# 95        1096   Employee_96   58           204   54855
# 96        1097   Employee_97   56           201   32158
# 97        1098   Employee_98   43           204   68016
# 98        1099   Employee_99   48           201   32400
# 99        1100  Employee_100   56           202   77322
#
# [100 rows x 5 columns]

# %%
df2 = pd.read_csv("datasets/departments1.csv")
df2
# Out:
#    DepartmentID DepartmentName   Location
# 0           201   Department_1       Pune
# 1           202   Department_2     Mumbai
# 2           203   Department_3    Chennai
# 3           205   Department_4     Mumbai
# 4           206   Department_5     Mumbai
# 5           207   Department_6  Bangalore
# 6           208   Department_7    Chennai
# 7           209   Department_8    Chennai
# 8           210   Department_9    Chennai
# 9           211  Department_10     Mumbai

# %% [markdown]
# ### **1. Different Types of Merges (Joins)**
# #### **a) Inner Join – only matching rows**

# %%
pd.merge(df1,df2,on="DepartmentID",how="inner")
# Out:
#     EmployeeID          Name  Age  DepartmentID  Salary DepartmentName  \
# 0         1001    Employee_1   50           201   71576   Department_1
# 1         1002    Employee_2   36           203   64353   Department_3
# 2         1003    Employee_3   29           201   42675   Department_1
# 3         1004    Employee_4   42           203   77733   Department_3
# 4         1005    Employee_5   40           202   69417   Department_2
# ..         ...           ...  ...           ...     ...            ...
# 72        1092   Employee_92   55           203   63191   Department_3
# 73        1093   Employee_93   54           202   72357   Department_2
# 74        1097   Employee_97   56           201   32158   Department_1
# 75        1099   Employee_99   48           201   32400   Department_1
# 76        1100  Employee_100   56           202   77322   Department_2
#
#    Location
# 0      Pune
# 1   Chennai
# 2      Pune
# 3   Chennai
# 4    Mumbai
# ..      ...
# 72  Chennai
# 73   Mumbai
# 74     Pune
# 75     Pune
# 76   Mumbai
#
# [77 rows x 7 columns]

# %% [markdown]
# #### **b) Left Join – all rows from left, matching from right**

# %%
pd.merge(df1,df2,on="DepartmentID",how="left")
# Out:
#     EmployeeID          Name  Age  DepartmentID  Salary DepartmentName  \
# 0         1001    Employee_1   50           201   71576   Department_1
# 1         1002    Employee_2   36           203   64353   Department_3
# 2         1003    Employee_3   29           201   42675   Department_1
# 3         1004    Employee_4   42           203   77733   Department_3
# 4         1005    Employee_5   40           202   69417   Department_2
# ..         ...           ...  ...           ...     ...            ...
# 95        1096   Employee_96   58           204   54855            NaN
# 96        1097   Employee_97   56           201   32158   Department_1
# 97        1098   Employee_98   43           204   68016            NaN
# 98        1099   Employee_99   48           201   32400   Department_1
# 99        1100  Employee_100   56           202   77322   Department_2
#
#    Location
# 0      Pune
# 1   Chennai
# 2      Pune
# 3   Chennai
# 4    Mumbai
# ..      ...
# 95      NaN
# 96     Pune
# 97      NaN
# 98     Pune
# 99   Mumbai
#
# [100 rows x 7 columns]

# %% [markdown]
# #### **c) Right Join – all rows from right, matching from left**

# %%
pd.merge(df1,df2,on="DepartmentID",how="right")
# Out:
#     EmployeeID         Name   Age  DepartmentID   Salary DepartmentName  \
# 0       1001.0   Employee_1  50.0           201  71576.0   Department_1
# 1       1003.0   Employee_3  29.0           201  42675.0   Department_1
# 2       1007.0   Employee_7  32.0           201  48664.0   Department_1
# 3       1008.0   Employee_8  32.0           201  26636.0   Department_1
# 4       1015.0  Employee_15  45.0           201  72323.0   Department_1
# ..         ...          ...   ...           ...      ...            ...
# 79         NaN          NaN   NaN           207      NaN   Department_6
# 80         NaN          NaN   NaN           208      NaN   Department_7
# 81         NaN          NaN   NaN           209      NaN   Department_8
# 82         NaN          NaN   NaN           210      NaN   Department_9
# 83         NaN          NaN   NaN           211      NaN  Department_10
#
#      Location
# 0        Pune
# 1        Pune
# 2        Pune
# 3        Pune
# 4        Pune
# ..        ...
# 79  Bangalore
# 80    Chennai
# 81    Chennai
# 82    Chennai
# 83     Mumbai
#
# [84 rows x 7 columns]

# %% [markdown]
# #### **d) Outer Join – all rows from both**

# %%
pd.merge(df1,df2,on="DepartmentID",how="outer")
# Out:
#      EmployeeID         Name   Age  DepartmentID   Salary DepartmentName  \
# 0        1001.0   Employee_1  50.0           201  71576.0   Department_1
# 1        1003.0   Employee_3  29.0           201  42675.0   Department_1
# 2        1007.0   Employee_7  32.0           201  48664.0   Department_1
# 3        1008.0   Employee_8  32.0           201  26636.0   Department_1
# 4        1015.0  Employee_15  45.0           201  72323.0   Department_1
# ..          ...          ...   ...           ...      ...            ...
# 102         NaN          NaN   NaN           207      NaN   Department_6
# 103         NaN          NaN   NaN           208      NaN   Department_7
# 104         NaN          NaN   NaN           209      NaN   Department_8
# 105         NaN          NaN   NaN           210      NaN   Department_9
# 106         NaN          NaN   NaN           211      NaN  Department_10
#
#       Location
# 0         Pune
# 1         Pune
# 2         Pune
# 3         Pune
# 4         Pune
# ..         ...
# 102  Bangalore
# 103    Chennai
# 104    Chennai
# 105    Chennai
# 106     Mumbai
#
# [107 rows x 7 columns]

# %%
df2 = pd.read_csv("datasets/departments2.csv")

# %% [markdown]
# ### **2. Merge on Different Column Names**

# %%
pd.merge(df1,df2,left_on="DepartmentID",right_on="Dep_ID")
# Out:
#     EmployeeID          Name  Age  DepartmentID  Salary  Dep_ID  \
# 0         1001    Employee_1   50           201   71576     201
# 1         1002    Employee_2   36           203   64353     203
# 2         1003    Employee_3   29           201   42675     201
# 3         1004    Employee_4   42           203   77733     203
# 4         1005    Employee_5   40           202   69417     202
# ..         ...           ...  ...           ...     ...     ...
# 72        1092   Employee_92   55           203   63191     203
# 73        1093   Employee_93   54           202   72357     202
# 74        1097   Employee_97   56           201   32158     201
# 75        1099   Employee_99   48           201   32400     201
# 76        1100  Employee_100   56           202   77322     202
#
#    DepartmentName Location
# 0    Department_1     Pune
# 1    Department_3  Chennai
# 2    Department_1     Pune
# 3    Department_3  Chennai
# 4    Department_2   Mumbai
# ..            ...      ...
# 72   Department_3  Chennai
# 73   Department_2   Mumbai
# 74   Department_1     Pune
# 75   Department_1     Pune
# 76   Department_2   Mumbai
#
# [77 rows x 8 columns]

# %% [markdown]
# ### **3. Merge with Multiple Keys**

# %%
pd.merge(df1,df2,on=["DepartmentID"])
# Out:
#     EmployeeID          Name  Age  DepartmentID  Salary DepartmentName  \
# 0         1001    Employee_1   50           201   71576   Department_1
# 1         1002    Employee_2   36           203   64353   Department_3
# 2         1003    Employee_3   29           201   42675   Department_1
# 3         1004    Employee_4   42           203   77733   Department_3
# 4         1005    Employee_5   40           202   69417   Department_2
# ..         ...           ...  ...           ...     ...            ...
# 72        1092   Employee_92   55           203   63191   Department_3
# 73        1093   Employee_93   54           202   72357   Department_2
# 74        1097   Employee_97   56           201   32158   Department_1
# 75        1099   Employee_99   48           201   32400   Department_1
# 76        1100  Employee_100   56           202   77322   Department_2
#
#    Location
# 0      Pune
# 1   Chennai
# 2      Pune
# 3   Chennai
# 4    Mumbai
# ..      ...
# 72  Chennai
# 73   Mumbai
# 74     Pune
# 75     Pune
# 76   Mumbai
#
# [77 rows x 7 columns]

# %% [markdown]
# ---
# ## **12. Concat Functions**
# #### **Concat** :to stack or combine DataFrames either vertically (rows) or horizontally (columns).
# ```python
#    pd.concat(objs, axis=0, join='outer', ignore_index=False)
#
#    # objs: A list or tuple of DataFrames
#    # axis=0: Stack vertically (default)
#    # axis=1: Stack horizontally
#    # join: 'outer' keeps all data (default), 'inner' keeps common columns/rows
#    # ignore_index: If True, reset index in the result
# ```

# %%
df1 = pd.read_csv("datasets/concat_df1.csv")

# %%
df2 = pd.read_csv("datasets/concat_df2.csv")

# %%
df3 = pd.read_csv("datasets/concat_df3.csv")
df3
# Out:
#    Salary
# 0   44560
# 1   29775
# 2   35137
# 3   38838
# 4   24365
# 5   23586
# 6   34013
# 7   46661
# 8   47329
# 9   35926

# %% [markdown]
# ### **1. Vertical Concatenation (Default)**

# %%
pd.concat([df1,df2])
# Out:
#    ID     Name   Age   Salary
# 0   1   Name_1  28.0      NaN
# 1   2   Name_2  33.0      NaN
# 2   3   Name_3  27.0      NaN
# 3   4   Name_4  35.0      NaN
# 4   5   Name_5  38.0      NaN
# 5   6   Name_6  32.0      NaN
# 6   7   Name_7  27.0      NaN
# 7   8   Name_8  21.0      NaN
# 8   9   Name_9  21.0      NaN
# 9  10  Name_10  24.0      NaN
# 0  11  Name_11   NaN  48548.0
# 1  12  Name_12   NaN  35718.0
# 2  13  Name_13   NaN  39508.0
# 3  14  Name_14   NaN  67971.0
# 4  15  Name_15   NaN  65388.0
# 5  16  Name_16   NaN  32813.0
# 6  17  Name_17   NaN  60842.0
# 7  18  Name_18   NaN  66898.0
# 8  19  Name_19   NaN  40742.0
# 9  20  Name_20   NaN  53057.0

# %% [markdown]
# ### **2. Vertical + Reset Index**

# %%
pd.concat([df1,df2],ignore_index=True)
# Out:
#     ID     Name   Age   Salary
# 0    1   Name_1  28.0      NaN
# 1    2   Name_2  33.0      NaN
# 2    3   Name_3  27.0      NaN
# 3    4   Name_4  35.0      NaN
# 4    5   Name_5  38.0      NaN
# 5    6   Name_6  32.0      NaN
# 6    7   Name_7  27.0      NaN
# 7    8   Name_8  21.0      NaN
# 8    9   Name_9  21.0      NaN
# 9   10  Name_10  24.0      NaN
# 10  11  Name_11   NaN  48548.0
# 11  12  Name_12   NaN  35718.0
# 12  13  Name_13   NaN  39508.0
# 13  14  Name_14   NaN  67971.0
# 14  15  Name_15   NaN  65388.0
# 15  16  Name_16   NaN  32813.0
# 16  17  Name_17   NaN  60842.0
# 17  18  Name_18   NaN  66898.0
# 18  19  Name_19   NaN  40742.0
# 19  20  Name_20   NaN  53057.0

# %% [markdown]
# ### **3. Horizontal Concatenation (Add Columns)**

# %%
pd.concat([df1,df3],axis=1)
# Out:
#    ID     Name  Age  Salary
# 0   1   Name_1   28   44560
# 1   2   Name_2   33   29775
# 2   3   Name_3   27   35137
# 3   4   Name_4   35   38838
# 4   5   Name_5   38   24365
# 5   6   Name_6   32   23586
# 6   7   Name_7   27   34013
# 7   8   Name_8   21   46661
# 8   9   Name_9   21   47329
# 9  10  Name_10   24   35926

# %% [markdown]
# ### **4. Outer Join (Default)**

# %%
pd.concat([df1,df2],join="outer",ignore_index=True)
# Out:
#     ID     Name   Age   Salary
# 0    1   Name_1  28.0      NaN
# 1    2   Name_2  33.0      NaN
# 2    3   Name_3  27.0      NaN
# 3    4   Name_4  35.0      NaN
# 4    5   Name_5  38.0      NaN
# 5    6   Name_6  32.0      NaN
# 6    7   Name_7  27.0      NaN
# 7    8   Name_8  21.0      NaN
# 8    9   Name_9  21.0      NaN
# 9   10  Name_10  24.0      NaN
# 10  11  Name_11   NaN  48548.0
# 11  12  Name_12   NaN  35718.0
# 12  13  Name_13   NaN  39508.0
# 13  14  Name_14   NaN  67971.0
# 14  15  Name_15   NaN  65388.0
# 15  16  Name_16   NaN  32813.0
# 16  17  Name_17   NaN  60842.0
# 17  18  Name_18   NaN  66898.0
# 18  19  Name_19   NaN  40742.0
# 19  20  Name_20   NaN  53057.0

# %% [markdown]
# ### **5. Inner Join (Only common columns)**

# %%
pd.concat([df1,df2],join="inner",ignore_index=True)
# Out:
#     ID     Name
# 0    1   Name_1
# 1    2   Name_2
# 2    3   Name_3
# 3    4   Name_4
# 4    5   Name_5
# 5    6   Name_6
# 6    7   Name_7
# 7    8   Name_8
# 8    9   Name_9
# 9   10  Name_10
# 10  11  Name_11
# 11  12  Name_12
# 12  13  Name_13
# 13  14  Name_14
# 14  15  Name_15
# 15  16  Name_16
# 16  17  Name_17
# 17  18  Name_18
# 18  19  Name_19
# 19  20  Name_20

# %% [markdown]
# ### **6. Concatenation with Mismatched Columns**

# %%
pd.concat([df1,df3],ignore_index=True)
# Out:
#       ID     Name   Age   Salary
# 0    1.0   Name_1  28.0      NaN
# 1    2.0   Name_2  33.0      NaN
# 2    3.0   Name_3  27.0      NaN
# 3    4.0   Name_4  35.0      NaN
# 4    5.0   Name_5  38.0      NaN
# 5    6.0   Name_6  32.0      NaN
# 6    7.0   Name_7  27.0      NaN
# 7    8.0   Name_8  21.0      NaN
# 8    9.0   Name_9  21.0      NaN
# 9   10.0  Name_10  24.0      NaN
# 10   NaN      NaN   NaN  44560.0
# 11   NaN      NaN   NaN  29775.0
# 12   NaN      NaN   NaN  35137.0
# 13   NaN      NaN   NaN  38838.0
# 14   NaN      NaN   NaN  24365.0
# 15   NaN      NaN   NaN  23586.0
# 16   NaN      NaN   NaN  34013.0
# 17   NaN      NaN   NaN  46661.0
# 18   NaN      NaN   NaN  47329.0
# 19   NaN      NaN   NaN  35926.0

# %% [markdown]
# ### **7. With Keys (Multilevel Index)**

# %%
pd.concat([df1, df2], keys=['first', 'second'])
# Out:
#           ID     Name   Age   Salary
# first  0   1   Name_1  28.0      NaN
#        1   2   Name_2  33.0      NaN
#        2   3   Name_3  27.0      NaN
#        3   4   Name_4  35.0      NaN
#        4   5   Name_5  38.0      NaN
#        5   6   Name_6  32.0      NaN
#        6   7   Name_7  27.0      NaN
#        7   8   Name_8  21.0      NaN
#        8   9   Name_9  21.0      NaN
#        9  10  Name_10  24.0      NaN
# second 0  11  Name_11   NaN  48548.0
#        1  12  Name_12   NaN  35718.0
#        2  13  Name_13   NaN  39508.0
#        3  14  Name_14   NaN  67971.0
#        4  15  Name_15   NaN  65388.0
#        5  16  Name_16   NaN  32813.0
#        6  17  Name_17   NaN  60842.0
#        7  18  Name_18   NaN  66898.0
#        8  19  Name_19   NaN  40742.0
#        9  20  Name_20   NaN  53057.0
