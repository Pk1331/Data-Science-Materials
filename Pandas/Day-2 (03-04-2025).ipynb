# %%
import pandas as pd

# %% [markdown]
# #### **6. Creating a DataFrame from CSV File**
# #### The read_csv() function in Pandas is used to read data from a CSV (Comma-Separated Values) file into a DataFrame.
# ##### **pd.read_csv(filepath, sep=',', header='infer', names=None, index_col=None, usecols=None, dtype=None, nrows=None, skiprows=None, encoding=None, etc.)**
# #### **Common Parameters:**
# | Parameter | Description |
# |-----------|-------------|
# | `filepath` | Path to the CSV file. |
# | `sep` | Delimiter (default: `,`). |
# | `header` | Row number to use as column names (`None` means no headers). |
# | `names` | Custom column names. |
# | `index_col` | Column to use as index. |
# | `usecols` | Load only specific columns. |
# | `dtype` | Data type of columns. |
# | `nrows` | Number of rows to read. |
# | `skiprows` | Number of rows to skip from the start. |
# | `encoding` | File encoding (e.g., `'utf-8'`). |
#
# ---

# %% [markdown]
# #### **1. Read a simple CSV file**

# %%
df = pd.read_csv("datasets/dummy.csv")
df.head()
# Out:
#    id        title                       content label
# 0   1  Fake News 1  This is fake news content 1.  fake
# 1   2  Fake News 2  This is fake news content 2.  real
# 2   3  Fake News 3  This is fake news content 3.  fake
# 3   4  Fake News 4  This is fake news content 4.  real
# 4   5  Fake News 5  This is fake news content 5.  fake

# %% [markdown]
# #### **2. Read a CSV file with a custom delimiter (;)**

# %%
df = pd.read_csv("datasets/dummy.csv",sep="-")
df.head()
# Out:
#                             id,title,content,label
# 0  1,Fake News 1,This is fake news content 1.,fake
# 1  2,Fake News 2,This is fake news content 2.,real
# 2  3,Fake News 3,This is fake news content 3.,fake
# 3  4,Fake News 4,This is fake news content 4.,real
# 4  5,Fake News 5,This is fake news content 5.,fake

# %% [markdown]
# #### **3. Read a CSV file without headers**

# %%
df = pd.read_csv("datasets/dummy.csv",header=None)
df.head()
# Out:
#     0            1                             2      3
# 0  id        title                       content  label
# 1   1  Fake News 1  This is fake news content 1.   fake
# 2   2  Fake News 2  This is fake news content 2.   real
# 3   3  Fake News 3  This is fake news content 3.   fake
# 4   4  Fake News 4  This is fake news content 4.   real

# %% [markdown]
# #### **4. Read a CSV file and set column names manually**

# %%
df = pd.read_csv("datasets/dummy.csv",names = ["Id","Name","Content","Label"])
df.head()
# Out:
#    Id         Name                       Content  Label
# 0  id        title                       content  label
# 1   1  Fake News 1  This is fake news content 1.   fake
# 2   2  Fake News 2  This is fake news content 2.   real
# 3   3  Fake News 3  This is fake news content 3.   fake
# 4   4  Fake News 4  This is fake news content 4.   real

# %% [markdown]
# #### **5. Read only specific columns**

# %%
df = pd.read_csv("datasets/dummy.csv",usecols = ["id","title"])
df
# Out:
#    id        title
# 0   1  Fake News 1
# 1   2  Fake News 2
# 2   3  Fake News 3
# 3   4  Fake News 4
# 4   5  Fake News 5

# %% [markdown]
# #### **6. Read CSV and set an index column**

# %%
df = pd.read_csv("datasets/dummy.csv",index_col="title")
df
# Out:
#              id                       content label
# title
# Fake News 1   1  This is fake news content 1.  fake
# Fake News 2   2  This is fake news content 2.  real
# Fake News 3   3  This is fake news content 3.  fake
# Fake News 4   4  This is fake news content 4.  real
# Fake News 5   5  This is fake news content 5.  fake

# %% [markdown]
# #### **7. Read only the first 5 rows**

# %%
df = pd.read_csv("datasets/dummy.csv",nrows=3)
df
# Out:
#    id        title                       content label
# 0   1  Fake News 1  This is fake news content 1.  fake
# 1   2  Fake News 2  This is fake news content 2.  real
# 2   3  Fake News 3  This is fake news content 3.  fake

# %% [markdown]
# #### **8. Skip the first 3 rows**

# %%
df = pd.read_csv("datasets/dummy.csv",skiprows=3)
df
# Out:
#    3  Fake News 3  This is fake news content 3.  fake
# 0  4  Fake News 4  This is fake news content 4.  real
# 1  5  Fake News 5  This is fake news content 5.  fake

# %% [markdown]
# #### **9. Read CSV with a specific data type**

# %%
df = pd.read_csv("datasets/dummy.csv",dtype={"fake":str})
df
# Out:
#    id        title                       content label
# 0   1  Fake News 1  This is fake news content 1.  fake
# 1   2  Fake News 2  This is fake news content 2.  real
# 2   3  Fake News 3  This is fake news content 3.  fake
# 3   4  Fake News 4  This is fake news content 4.  real
# 4   5  Fake News 5  This is fake news content 5.  fake

# %% [markdown]
# #### **10. Read CSV with a different encoding (e.g., UTF-8)**

# %%
df = pd.read_csv("datasets/dummy.csv",encoding="UTF-8")
df
# Out:
#    id        title                       content label
# 0   1  Fake News 1  This is fake news content 1.  fake
# 1   2  Fake News 2  This is fake news content 2.  real
# 2   3  Fake News 3  This is fake news content 3.  fake
# 3   4  Fake News 4  This is fake news content 4.  real
# 4   5  Fake News 5  This is fake news content 5.  fake

# %% [markdown]
# # Operations

# %%
df = pd.read_csv("datasets/chocolate.csv")
df
# Out:
#           Sales Person    Country              Product       Date    Amount  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22   $5,320
# 1          Van Tuxwell      India        85% Dark Bars  01-Aug-22   $7,896
# 2         Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22   $4,501
# 3         Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22  $12,726
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22  $13,685
# ...                ...        ...                  ...        ...       ...
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims  17-May-22   $4,410
# 1090    Jehu Rudeforth        USA           White Choc  07-Jun-22   $6,559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup  26-Jul-22     $574
# 1092    Dotty Strutley      India              Eclairs  28-Jul-22   $2,086
# 1093  Karlen McCaffrey      India       70% Dark Bites  23-May-22   $5,075
#
#       Boxes Shipped
# 0               180
# 1                94
# 2                91
# 3               342
# 4               184
# ...             ...
# 1089            323
# 1090            119
# 1091            217
# 1092            384
# 1093            344
#
# [1094 rows x 6 columns]

# %% [markdown]
# ## **1. Data Inspection & Information Functions**

# %% [markdown]
# #### **df.head()**: View the first 5 rows of the DataFrame | **df.head(n)**

# %%
df.head()
# Out:
#      Sales Person    Country              Product       Date    Amount  \
# 0  Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22   $5,320
# 1     Van Tuxwell      India        85% Dark Bars  01-Aug-22   $7,896
# 2    Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22   $4,501
# 3    Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22  $12,726
# 4  Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22  $13,685
#
#    Boxes Shipped
# 0            180
# 1             94
# 2             91
# 3            342
# 4            184

# %%
df.head(10)
# Out:
#       Sales Person      Country              Product       Date    Amount  \
# 0   Jehu Rudeforth           UK      Mint Chip Choco  04-Jan-22   $5,320
# 1      Van Tuxwell        India        85% Dark Bars  01-Aug-22   $7,896
# 2     Gigi Bohling        India  Peanut Butter Cubes  07-Jul-22   $4,501
# 3     Jan Morforth    Australia  Peanut Butter Cubes  27-Apr-22  $12,726
# 4   Jehu Rudeforth           UK  Peanut Butter Cubes  24-Feb-22  $13,685
# 5      Van Tuxwell        India   Smooth Sliky Salty  06-Jun-22   $5,376
# 6       Oby Sorrel           UK      99% Dark & Pure  25-Jan-22  $13,685
# 7  Gunar Cockshoot    Australia          After Nines  24-Mar-22   $3,080
# 8   Jehu Rudeforth  New Zealand       50% Dark Bites  20-Apr-22   $3,990
# 9      Brien Boise    Australia      99% Dark & Pure  04-Jul-22   $2,835
#
#    Boxes Shipped
# 0            180
# 1             94
# 2             91
# 3            342
# 4            184
# 5             38
# 6            176
# 7             73
# 8             59
# 9            102

# %% [markdown]
# #### **df.tail()**: View the last 5 rows of the DataFrame. | **df.tail(n)**

# %%
df.tail()
# Out:
#           Sales Person    Country              Product       Date   Amount  \
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims  17-May-22  $4,410
# 1090    Jehu Rudeforth        USA           White Choc  07-Jun-22  $6,559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup  26-Jul-22    $574
# 1092    Dotty Strutley      India              Eclairs  28-Jul-22  $2,086
# 1093  Karlen McCaffrey      India       70% Dark Bites  23-May-22  $5,075
#
#       Boxes Shipped
# 1089            323
# 1090            119
# 1091            217
# 1092            384
# 1093            344

# %%
df.tail(10)
# Out:
#              Sales Person      Country              Product       Date  \
# 1084      Roddy Speechley        India       50% Dark Bites  14-Mar-22
# 1085         Barr Faughny  New Zealand      99% Dark & Pure  24-May-22
# 1086  Dennison Crosswaite       Canada  Organic Choco Syrup  28-Jan-22
# 1087       Beverie Moffet        India         Almond Choco  24-May-22
# 1088          Brien Boise    Australia  Peanut Butter Cubes  19-Aug-22
# 1089     Karlen McCaffrey    Australia  Spicy Special Slims  17-May-22
# 1090       Jehu Rudeforth          USA           White Choc  07-Jun-22
# 1091         Ches Bonnell       Canada  Organic Choco Syrup  26-Jul-22
# 1092       Dotty Strutley        India              Eclairs  28-Jul-22
# 1093     Karlen McCaffrey        India       70% Dark Bites  23-May-22
#
#        Amount  Boxes Shipped
# 1084  $8,337              12
# 1085  $8,134             195
# 1086  $8,491              75
# 1087  $3,066              96
# 1088    $301             205
# 1089  $4,410             323
# 1090  $6,559             119
# 1091    $574             217
# 1092  $2,086             384
# 1093  $5,075             344

# %% [markdown]
# #### **df.sample()**: View the random 1 rows of the DataFrame. | **df.sample(n)**

# %%
df.sample()
# Out:
#        Sales Person Country        Product       Date   Amount  Boxes Shipped
# 289  Mallorie Waber     USA  85% Dark Bars  11-May-22  $2,632             108

# %%
df.sample(5)
# Out:
#              Sales Person Country               Product       Date   Amount  \
# 802          Husein Augar      UK          Almond Choco  17-May-22  $8,309
# 829        Wilone O'Kielt   India  Caramel Stuffed Bars  13-Jan-22  $4,179
# 493          Husein Augar  Canada               Eclairs  17-Jan-22  $3,696
# 1086  Dennison Crosswaite  Canada   Organic Choco Syrup  28-Jan-22  $8,491
# 1028          Van Tuxwell  Canada         Drinking Coco  15-Jun-22  $4,900
#
#       Boxes Shipped
# 802             166
# 829             276
# 493             233
# 1086             75
# 1028            709

# %% [markdown]
# #### **df.info()**: Get a concise summary of the DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1094 entries, 0 to 1093
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales Person   1094 non-null   object
#  1   Country        1094 non-null   object
#  2   Product        1094 non-null   object
#  3   Date           1094 non-null   object
#  4   Amount         1094 non-null   object
#  5   Boxes Shipped  1094 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 51.4+ KB

# %% [markdown]
# #### **df.describe()**: Summary statistics for numerical columns.

# %%
df.describe()
# Out:
#        Boxes Shipped
# count    1094.000000
# mean      161.797989
# std       121.544145
# min         1.000000
# 25%        70.000000
# 50%       135.000000
# 75%       228.750000
# max       709.000000

# %% [markdown]
# #### **df.dtypes**: Check data types of columns.

# %%
df.dtypes
# Out:
# Sales Person     object
# Country          object
# Product          object
# Date             object
# Amount           object
# Boxes Shipped     int64
# dtype: object

# %% [markdown]
# #### **df.columns**: List column names

# %%
df.columns
# Out:
# Index(['Sales Person', 'Country', 'Product', 'Date', 'Amount',
#        'Boxes Shipped'],
#       dtype='object')

# %% [markdown]
# #### **df.index**: Display the index range.

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1094, step=1)

# %% [markdown]
# #### **df.shape**: Get the dimensions of the DataFrame.(rows,cols)

# %%
df.shape
# Out:
# (1094, 6)

# %% [markdown]
# #### **df.memory_usage()** :the memory usage of each column in bytes.
# #### The index represents the column names.

# %%
df.memory_usage()
# Out:
# Index             132
# Sales Person     8752
# Country          8752
# Product          8752
# Date             8752
# Amount           8752
# Boxes Shipped    8752
# dtype: int64

# %% [markdown]
# #### Exclude the index from the output:

# %%
df.memory_usage(index=False)
# Out:
# Sales Person     8752
# Country          8752
# Product          8752
# Date             8752
# Amount           8752
# Boxes Shipped    8752
# dtype: int64

# %% [markdown]
# #### Get the total memory usage of the entire DataFrame:

# %%
df.memory_usage(deep=True).sum()
# Out:
# np.int64(331885)

# %% [markdown]
# ## **2. Indexing & Selection Functions**

# %% [markdown]
# ## <span style="color:green;">Selecting Columns</span>

# %% [markdown]
# #### **df['column']**: Select a single column.

# %%
df["Country"]
# Out:
# 0              UK
# 1           India
# 2           India
# 3       Australia
# 4              UK
#           ...
# 1089    Australia
# 1090          USA
# 1091       Canada
# 1092        India
# 1093        India
# Name: Country, Length: 1094, dtype: object

# %% [markdown]
# #### **df[ ['col1', 'col2'] ]**: Select multiple columns.

# %%
df[["Product","Date"]]
# Out:
#                   Product       Date
# 0         Mint Chip Choco  04-Jan-22
# 1           85% Dark Bars  01-Aug-22
# 2     Peanut Butter Cubes  07-Jul-22
# 3     Peanut Butter Cubes  27-Apr-22
# 4     Peanut Butter Cubes  24-Feb-22
# ...                   ...        ...
# 1089  Spicy Special Slims  17-May-22
# 1090           White Choc  07-Jun-22
# 1091  Organic Choco Syrup  26-Jul-22
# 1092              Eclairs  28-Jul-22
# 1093       70% Dark Bites  23-May-22
#
# [1094 rows x 2 columns]

# %% [markdown]
# ## <span style="color:green;">Selecting Rows</span>

# %% [markdown]
# #### **df.loc[0]**: Select the first row by index label

# %%
df.loc[0]
# Out:
# Sales Person      Jehu Rudeforth
# Country                       UK
# Product          Mint Chip Choco
# Date                   04-Jan-22
# Amount                   $5,320
# Boxes Shipped                180
# Name: 0, dtype: object

# %% [markdown]
# #### **df.iloc[0]**: Select the first row by position.

# %%
df.iloc[1]
# Out:
# Sales Person       Van Tuxwell
# Country                  India
# Product          85% Dark Bars
# Date                 01-Aug-22
# Amount                 $7,896
# Boxes Shipped               94
# Name: 1, dtype: object

# %% [markdown]
# #### **df.loc[df["Column_Name"] condition]** : Filter rows based on condition

# %%
df.loc[df["Boxes Shipped"] >500]
# Out:
#           Sales Person      Country               Product       Date  \
# 39    Karlen McCaffrey        India    Manuka Honey Choco  04-Jul-22
# 109       Jan Morforth        India   Spicy Special Slims  12-Apr-22
# 121      Kelci Walkden    Australia               Eclairs  23-Mar-22
# 171      Kelci Walkden        India           After Nines  07-Jan-22
# 340        Kaine Padly           UK    Smooth Sliky Salty  08-Jun-22
# 458    Roddy Speechley        India  Caramel Stuffed Bars  30-May-22
# 672     Jehu Rudeforth       Canada          Orange Choco  23-Jun-22
# 692     Dotty Strutley          USA         85% Dark Bars  25-Apr-22
# 730   Karlen McCaffrey    Australia        50% Dark Bites  17-Jan-22
# 765    Gunar Cockshoot        India   Baker's Choco Chips  18-Mar-22
# 769   Karlen McCaffrey       Canada        70% Dark Bites  24-Jun-22
# 852     Marney O'Breen       Canada  Caramel Stuffed Bars  23-Feb-22
# 865        Kaine Padly  New Zealand    Smooth Sliky Salty  12-Apr-22
# 875     Beverie Moffet  New Zealand         Drinking Coco  12-Jan-22
# 978     Mallorie Waber       Canada  Caramel Stuffed Bars  10-Jun-22
# 1028       Van Tuxwell       Canada         Drinking Coco  15-Jun-22
# 1070        Oby Sorrel       Canada               Eclairs  19-May-22
#
#         Amount  Boxes Shipped
# 39     $2,443             581
# 109    $1,939             520
# 121    $7,273             547
# 171    $1,687             520
# 340    $9,016             554
# 458    $8,911             543
# 672    $3,857             512
# 692   $10,220             508
# 730    $6,678             708
# 765    $2,191             524
# 769    $7,714             597
# 852    $1,372             614
# 865        $7             518
# 875    $1,141             518
# 978    $4,844             539
# 1028   $4,900             709
# 1070   $6,111             591

# %% [markdown]
# ##### Selectings Records Country is equal to India

# %%
df.loc[df['Country']=="India"]
# Out:
#           Sales Person Country              Product       Date    Amount  \
# 1          Van Tuxwell   India        85% Dark Bars  01-Aug-22   $7,896
# 2         Gigi Bohling   India  Peanut Butter Cubes  07-Jul-22   $4,501
# 5          Van Tuxwell   India   Smooth Sliky Salty  06-Jun-22   $5,376
# 25    Karlen McCaffrey   India     Fruit & Nut Bars  26-Jan-22     $168
# 39    Karlen McCaffrey   India   Manuka Honey Choco  04-Jul-22   $2,443
# ...                ...     ...                  ...        ...       ...
# 1075   Roddy Speechley   India  Spicy Special Slims  22-Mar-22  $10,647
# 1084   Roddy Speechley   India       50% Dark Bites  14-Mar-22   $8,337
# 1087    Beverie Moffet   India         Almond Choco  24-May-22   $3,066
# 1092    Dotty Strutley   India              Eclairs  28-Jul-22   $2,086
# 1093  Karlen McCaffrey   India       70% Dark Bites  23-May-22   $5,075
#
#       Boxes Shipped
# 1                94
# 2                91
# 5                38
# 25              321
# 39              581
# ...             ...
# 1075            173
# 1084             12
# 1087             96
# 1092            384
# 1093            344
#
# [184 rows x 6 columns]

# %% [markdown]
# #### **df.loc[row_label, column_name]** : Select a specific element by label

# %%
df.loc[1070,"Product"]
# Out:
# 'Eclairs'

# %% [markdown]
# #### **df.iloc[row_index, column_index]** : Select a specific element by position.

# %%
df.iloc[978,0]
# Out:
# 'Mallorie Waber'

# %% [markdown]
# #### **df.iloc[row_start:row_end, col_start:col_end]**: Slice rows and columns.

# %%
df.iloc[0:11,1:3]
# Out:
#         Country              Product
# 0            UK      Mint Chip Choco
# 1         India        85% Dark Bars
# 2         India  Peanut Butter Cubes
# 3     Australia  Peanut Butter Cubes
# 4            UK  Peanut Butter Cubes
# 5         India   Smooth Sliky Salty
# 6            UK      99% Dark & Pure
# 7     Australia          After Nines
# 8   New Zealand       50% Dark Bites
# 9     Australia      99% Dark & Pure
# 10           UK   Smooth Sliky Salty

# %% [markdown]
# #### **df.set_index()** : set a column (or multiple columns) as the index of a DataFrame.
# **`df.set_index(keys, drop=True, append=False, inplace=False)`**

# %% [markdown]
# ### **Parameters**
# | Parameter | Description |
# |-----------|------------|
# | `keys` | The column (or list of columns) to set as index. |
# | `drop` | **Default = True**. Drops the column from the DataFrame after setting it as index. |
# | `append` | **Default = False**. If `True`, adds the new index without removing the existing index. |
# | `inplace` | **Default = False**. If `True`, modifies the DataFrame directly without returning a new one. |
#
# ---
#
#
# ```

# %% [markdown]
# #### **1. Set a Single Column as Index**

# %%
df.set_index("Country")
# Out:
#                Sales Person              Product       Date    Amount  \
# Country
# UK           Jehu Rudeforth      Mint Chip Choco  04-Jan-22   $5,320
# India           Van Tuxwell        85% Dark Bars  01-Aug-22   $7,896
# India          Gigi Bohling  Peanut Butter Cubes  07-Jul-22   $4,501
# Australia      Jan Morforth  Peanut Butter Cubes  27-Apr-22  $12,726
# UK           Jehu Rudeforth  Peanut Butter Cubes  24-Feb-22  $13,685
# ...                     ...                  ...        ...       ...
# Australia  Karlen McCaffrey  Spicy Special Slims  17-May-22   $4,410
# USA          Jehu Rudeforth           White Choc  07-Jun-22   $6,559
# Canada         Ches Bonnell  Organic Choco Syrup  26-Jul-22     $574
# India        Dotty Strutley              Eclairs  28-Jul-22   $2,086
# India      Karlen McCaffrey       70% Dark Bites  23-May-22   $5,075
#
#            Boxes Shipped
# Country
# UK                   180
# India                 94
# India                 91
# Australia            342
# UK                   184
# ...                  ...
# Australia            323
# USA                  119
# Canada               217
# India                384
# India                344
#
# [1094 rows x 5 columns]

# %% [markdown]
# #### **By default inplace is False so original dataframe `cannot changed` here.**

# %%
df
# Out:
#           Sales Person    Country              Product       Date    Amount  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22   $5,320
# 1          Van Tuxwell      India        85% Dark Bars  01-Aug-22   $7,896
# 2         Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22   $4,501
# 3         Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22  $12,726
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22  $13,685
# ...                ...        ...                  ...        ...       ...
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims  17-May-22   $4,410
# 1090    Jehu Rudeforth        USA           White Choc  07-Jun-22   $6,559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup  26-Jul-22     $574
# 1092    Dotty Strutley      India              Eclairs  28-Jul-22   $2,086
# 1093  Karlen McCaffrey      India       70% Dark Bites  23-May-22   $5,075
#
#       Boxes Shipped
# 0               180
# 1                94
# 2                91
# 3               342
# 4               184
# ...             ...
# 1089            323
# 1090            119
# 1091            217
# 1092            384
# 1093            344
#
# [1094 rows x 6 columns]

# %% [markdown]
# #### **2. Keep the Original Column (drop=False)**

# %%
df.set_index("Country",drop=False)
# Out:
#                Sales Person    Country              Product       Date  \
# Country
# UK           Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22
# India           Van Tuxwell      India        85% Dark Bars  01-Aug-22
# India          Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22
# Australia      Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22
# UK           Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22
# ...                     ...        ...                  ...        ...
# Australia  Karlen McCaffrey  Australia  Spicy Special Slims  17-May-22
# USA          Jehu Rudeforth        USA           White Choc  07-Jun-22
# Canada         Ches Bonnell     Canada  Organic Choco Syrup  26-Jul-22
# India        Dotty Strutley      India              Eclairs  28-Jul-22
# India      Karlen McCaffrey      India       70% Dark Bites  23-May-22
#
#              Amount  Boxes Shipped
# Country
# UK          $5,320             180
# India       $7,896              94
# India       $4,501              91
# Australia  $12,726             342
# UK         $13,685             184
# ...             ...            ...
# Australia   $4,410             323
# USA         $6,559             119
# Canada        $574             217
# India       $2,086             384
# India       $5,075             344
#
# [1094 rows x 6 columns]

# %% [markdown]
# #### **By default inplace is False so original dataframe `cannot changed`here.**

# %%
df
# Out:
#           Sales Person    Country              Product       Date    Amount  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22   $5,320
# 1          Van Tuxwell      India        85% Dark Bars  01-Aug-22   $7,896
# 2         Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22   $4,501
# 3         Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22  $12,726
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22  $13,685
# ...                ...        ...                  ...        ...       ...
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims  17-May-22   $4,410
# 1090    Jehu Rudeforth        USA           White Choc  07-Jun-22   $6,559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup  26-Jul-22     $574
# 1092    Dotty Strutley      India              Eclairs  28-Jul-22   $2,086
# 1093  Karlen McCaffrey      India       70% Dark Bites  23-May-22   $5,075
#
#       Boxes Shipped
# 0               180
# 1                94
# 2                91
# 3               342
# 4               184
# ...             ...
# 1089            323
# 1090            119
# 1091            217
# 1092            384
# 1093            344
#
# [1094 rows x 6 columns]

# %%
df.set_index("Country",inplace=True)

# %% [markdown]
# #### **By default inplace is True so original dataframe `changed` here.**

# %%
df
# Out:
#                Sales Person              Product       Date    Amount  \
# Country
# UK           Jehu Rudeforth      Mint Chip Choco  04-Jan-22   $5,320
# India           Van Tuxwell        85% Dark Bars  01-Aug-22   $7,896
# India          Gigi Bohling  Peanut Butter Cubes  07-Jul-22   $4,501
# Australia      Jan Morforth  Peanut Butter Cubes  27-Apr-22  $12,726
# UK           Jehu Rudeforth  Peanut Butter Cubes  24-Feb-22  $13,685
# ...                     ...                  ...        ...       ...
# Australia  Karlen McCaffrey  Spicy Special Slims  17-May-22   $4,410
# USA          Jehu Rudeforth           White Choc  07-Jun-22   $6,559
# Canada         Ches Bonnell  Organic Choco Syrup  26-Jul-22     $574
# India        Dotty Strutley              Eclairs  28-Jul-22   $2,086
# India      Karlen McCaffrey       70% Dark Bites  23-May-22   $5,075
#
#            Boxes Shipped
# Country
# UK                   180
# India                 94
# India                 91
# Australia            342
# UK                   184
# ...                  ...
# Australia            323
# USA                  119
# Canada               217
# India                384
# India                344
#
# [1094 rows x 5 columns]

# %% [markdown]
# #### **3. Set Multiple Columns as Index**

# %%
df2 = pd.read_csv("datasets/chocolate.csv")
df2
# Out:
#           Sales Person    Country              Product       Date    Amount  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22   $5,320
# 1          Van Tuxwell      India        85% Dark Bars  01-Aug-22   $7,896
# 2         Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22   $4,501
# 3         Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22  $12,726
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22  $13,685
# ...                ...        ...                  ...        ...       ...
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims  17-May-22   $4,410
# 1090    Jehu Rudeforth        USA           White Choc  07-Jun-22   $6,559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup  26-Jul-22     $574
# 1092    Dotty Strutley      India              Eclairs  28-Jul-22   $2,086
# 1093  Karlen McCaffrey      India       70% Dark Bites  23-May-22   $5,075
#
#       Boxes Shipped
# 0               180
# 1                94
# 2                91
# 3               342
# 4               184
# ...             ...
# 1089            323
# 1090            119
# 1091            217
# 1092            384
# 1093            344
#
# [1094 rows x 6 columns]

# %%
df2.set_index(["Date","Country"],inplace=True)
df2
# Out:
#                          Sales Person              Product    Amount  \
# Date      Country
# 04-Jan-22 UK           Jehu Rudeforth      Mint Chip Choco   $5,320
# 01-Aug-22 India           Van Tuxwell        85% Dark Bars   $7,896
# 07-Jul-22 India          Gigi Bohling  Peanut Butter Cubes   $4,501
# 27-Apr-22 Australia      Jan Morforth  Peanut Butter Cubes  $12,726
# 24-Feb-22 UK           Jehu Rudeforth  Peanut Butter Cubes  $13,685
# ...                               ...                  ...       ...
# 17-May-22 Australia  Karlen McCaffrey  Spicy Special Slims   $4,410
# 07-Jun-22 USA          Jehu Rudeforth           White Choc   $6,559
# 26-Jul-22 Canada         Ches Bonnell  Organic Choco Syrup     $574
# 28-Jul-22 India        Dotty Strutley              Eclairs   $2,086
# 23-May-22 India      Karlen McCaffrey       70% Dark Bites   $5,075
#
#                      Boxes Shipped
# Date      Country
# 04-Jan-22 UK                   180
# 01-Aug-22 India                 94
# 07-Jul-22 India                 91
# 27-Apr-22 Australia            342
# 24-Feb-22 UK                   184
# ...                            ...
# 17-May-22 Australia            323
# 07-Jun-22 USA                  119
# 26-Jul-22 Canada               217
# 28-Jul-22 India                384
# 23-May-22 India                344
#
# [1094 rows x 4 columns]

# %% [markdown]
# #### **df.reset_index()** - revert back to default indexing.

# %%
df2.reset_index(inplace=True)
df2
# Out:
#            Date    Country      Sales Person              Product    Amount  \
# 0     04-Jan-22         UK    Jehu Rudeforth      Mint Chip Choco   $5,320
# 1     01-Aug-22      India       Van Tuxwell        85% Dark Bars   $7,896
# 2     07-Jul-22      India      Gigi Bohling  Peanut Butter Cubes   $4,501
# 3     27-Apr-22  Australia      Jan Morforth  Peanut Butter Cubes  $12,726
# 4     24-Feb-22         UK    Jehu Rudeforth  Peanut Butter Cubes  $13,685
# ...         ...        ...               ...                  ...       ...
# 1089  17-May-22  Australia  Karlen McCaffrey  Spicy Special Slims   $4,410
# 1090  07-Jun-22        USA    Jehu Rudeforth           White Choc   $6,559
# 1091  26-Jul-22     Canada      Ches Bonnell  Organic Choco Syrup     $574
# 1092  28-Jul-22      India    Dotty Strutley              Eclairs   $2,086
# 1093  23-May-22      India  Karlen McCaffrey       70% Dark Bites   $5,075
#
#       Boxes Shipped
# 0               180
# 1                94
# 2                91
# 3               342
# 4               184
# ...             ...
# 1089            323
# 1090            119
# 1091            217
# 1092            384
# 1093            344
#
# [1094 rows x 6 columns]
